# %% [markdown]
# # Libraries

# %%
# !pip install unidecode

# %%
# !sudo add-apt-repository -y ppa:fbirlik/sqlite3
# !sudo apt update
# !sudo apt-get install -y sqlite3

# %%
import os
import sqlite3
import requests
import pandas as pd

from unidecode import unidecode

# %% [markdown]
# # Carregando dados VRA

# %%
# Get all files
path = '/content/drive/MyDrive/data_eleflow/VRA/'
files = [
  path + file for file in os.listdir(path)
]

# Concat data
data = []
for file in files:
  data.append(pd.read_json(file, encoding='utf-8-sig'))
vra_data = pd.concat(data)

# Rename Header -> snake_case
header_name = {
    "ICAOEmpresaAérea": "icao_empresa_aerea",
    "NúmeroVoo": "numero_voo",
    "CódigoAutorização": "codigo_autorizacao",
    "CódigoTipoLinha": "codigo_tipo_linha",
    "ICAOAeródromoOrigem": "icao_aerodromo_origem",
    "ICAOAeródromoDestino": "icao_aerodromo_destino",
    "PartidaPrevista": "partida_prevista",
    "PartidaReal": "partida_real",
    "ChegadaPrevista": "chegada_prevista",
    "ChegadaReal": "chegada_real",
    "SituaçãoVoo": "situacao_voo",
    "CódigoJustificativa": "codigo_justificativa"
}
vra_data.rename(columns=header_name, inplace=True)
vra_data
# Out:
#       icao_empresa_aerea numero_voo codigo_autorizacao codigo_tipo_linha  \
# 0                    AEA       0057                  0                 X
# 1                    AEA       0057                  0                 X
# 2                    AEA       0057                  0                 X
# 3                    MWM       5800                  0                 C
# 4                    MWM       5800                  0                 C
# ...                  ...        ...                ...               ...
# 40950                AZU       4411                  0                 N
# 40951                AZU       4411                  0                 N
# 40952                AZU       4411                  0                 N
# 40953                AZU       4412                  0                 N
# 40954                AZU       4412                  0                 N
#
#       icao_aerodromo_origem icao_aerodromo_destino     partida_prevista  \
# 0                      LEMD                   SBGR  2021-10-01 18:45:00
# 1                      LEMD                   SBGR  2021-10-03 18:45:00
# 2                      LEMD                   SBGR  2021-10-06 18:45:00
# 3                      SBBR                   SBEG  2021-10-12 01:25:00
# 4                      SBBR                   SBEG  2021-10-13 01:25:00
# ...                     ...                    ...                  ...
# 40950                  SBCF                   SBMA  2021-06-28 23:00:00
# 40951                  SBCF                   SBMA  2021-06-29 23:00:00
# 40952                  SBCF                   SBMA  2021-06-30 23:00:00
# 40953                  SBCF                   SBVT  2021-06-01 21:40:00
# 40954                  SBCF                   SBVT  2021-06-02 21:40:00
#
#               partida_real     chegada_prevista         chegada_real  \
# 0      2021-10-01 19:24:00  2021-10-02 05:25:00  2021-10-02 05:06:00
# 1      2021-10-03 20:27:00  2021-10-04 05:25:00  2021-10-04 05:39:00
# 2      2021-10-06 19:18:00  2021-10-07 05:25:00  2021-10-07 05:05:00
# 3      2021-10-12 01:22:00  2021-10-12 04:25:00  2021-10-12 04:18:00
# 4                     None  2021-10-13 04:25:00                 None
# ...                    ...                  ...                  ...
# 40950  2021-06-28 22:51:00  2021-06-29 01:35:00  2021-06-29 01:23:00
# 40951  2021-06-29 22:58:00  2021-06-30 01:35:00  2021-06-30 01:32:00
# 40952  2021-06-30 22:56:00  2021-07-01 01:35:00  2021-07-01 01:33:00
# 40953  2021-06-01 21:36:00  2021-06-01 22:45:00  2021-06-01 22:30:00
# 40954  2021-06-02 21:41:00  2021-06-02 22:45:00  2021-06-02 22:38:00
#
#       situacao_voo codigo_justificativa
# 0        REALIZADO                  N/A
# 1        REALIZADO                  N/A
# 2        REALIZADO                  N/A
# 3        REALIZADO                  N/A
# 4        CANCELADO                  N/A
# ...            ...                  ...
# 40950    REALIZADO                  N/A
# 40951    REALIZADO                  N/A
# 40952    REALIZADO                  N/A
# 40953    REALIZADO                  N/A
# 40954    REALIZADO                  N/A
#
# [535803 rows x 12 columns]

# %% [markdown]
# # Get all ICAO aerodromos

# %%
icao_codes = set()

for origin_icao, destiny_icao in zip(vra_data['icao_aerodromo_origem'], vra_data['icao_aerodromo_destino']):
  icao_codes.add(origin_icao)
  icao_codes.add(destiny_icao)

icao_codes
# Out:
# {'CYHM',
#  'CYUL',
#  'CYYZ',
#  'DGAA',
#  'DIAP',
#  'DNKN',
#  'DNMM',
#  'EBBR',
#  'EBLG',
#  'EBOS',
#  'EDDF',
#  'EDDK',
#  'EDFH',
#  'EGBB',
#  'EGLL',
#  'EGNX',
#  'EGSS',
#  'EHAM',
#  'EHBK',
#  'EKCH',
#  'ELLX',
#  'FAOR',
#  'FNLU',
#  'FQMA',
#  'FYWH',
#  'FZAA',
#  'GBYD',
#  'GCTS',
#  'GMAD',
#  'GMMN',
#  'GOBD',
#  'GUCY',
#  'GVAC',
#  'HAAB',
#  'HKJK',
#  'HLLM',
#  'HSSS',
#  'KAEX',
#  'KATL',
#  'KAUH',
#  'KAUS',
#  'KBOS',
#  'KCVG',
#  'KDFW',
#  'KEWR',
#  'KFLL',
#  'KHSV',
#  'KIAD',
#  'KIAH',
#  'KIWA',
#  'KJFK',
#  'KLAX',
#  'KMEM',
#  'KMIA',
#  'KORD',
#  'KPUC',
#  'KPVG',
#  'KSTL',
#  'LEBL',
#  'LEMD',
#  'LEZG',
#  'LFLX',
#  'LFOK',
#  'LFPG',
#  'LIMC',
#  'LIRF',
#  'LKMT',
#  'LPPR',
#  'LPPT',
#  'LRCK',
#  'LSZH',
#  'LTBA',
#  'LTFM',
#  'LYBE',
#  'MDPC',
#  'MDSD',
#  'MGGT',
#  'MKJP',
#  'MMGL',
#  'MMMD',
#  'MMMX',
#  'MMMY',
#  'MMUN',
#  'MNMG',
#  'MPTO',
#  'MSLP',
#  'MTPP',
#  'MUHA',
#  'NZAA',
#  'OEJN',
#  'OMAA',
#  'OMDB',
#  'OMSJ',
#  'OOMS',
#  'OTHH',
#  'PANC',
#  'RJAA',
#  'RKSI',
#  'SAAR',
#  'SABE',
#  'SACO',
#  'SAEZ',
#  'SAME',
#  'SANT',
#  'SANU',
#  'SARI',
#  'SBAC',
#  'SBAE',
#  'SBAR',
#  'SBAT',
#  'SBAU',
#  'SBBE',
#  'SBBG',
#  'SBBH',
#  'SBBP',
#  'SBBR',
#  'SBBU',
#  'SBBV',
#  'SBBW',
#  'SBCA',
#  'SBCB',
#  'SBCD',
#  'SBCF',
#  'SBCG',
#  'SBCH',
#  'SBCJ',
#  'SBCN',
#  'SBCP',
#  'SBCR',
#  'SBCT',
#  'SBCX',
#  'SBCY',
#  'SBCZ',
#  'SBDB',
#  'SBDN',
#  'SBDO',
#  'SBEG',
#  'SBFI',
#  'SBFL',
#  'SBFN',
#  'SBFZ',
#  'SBGL',
#  'SBGO',
#  'SBGR',
#  'SBGV',
#  'SBHT',
#  'SBIH',
#  'SBIL',
#  'SBIZ',
#  'SBJA',
#  'SBJD',
#  'SBJE',
#  'SBJI',
#  'SBJP',
#  'SBJU',
#  'SBJV',
#  'SBKG',
#  'SBKP',
#  'SBLO',
#  'SBMA',
#  'SBMD',
#  'SBME',
#  'SBMG',
#  'SBMK',
#  'SBML',
#  'SBMO',
#  'SBMQ',
#  'SBMS',
#  'SBNF',
#  'SBNM',
#  'SBPA',
#  'SBPB',
#  'SBPF',
#  'SBPG',
#  'SBPJ',
#  'SBPK',
#  'SBPL',
#  'SBPO',
#  'SBPS',
#  'SBPV',
#  'SBRB',
#  'SBRD',
#  'SBRF',
#  'SBRJ',
#  'SBRP',
#  'SBSG',
#  'SBSI',
#  'SBSJ',
#  'SBSL',
#  'SBSM',
#  'SBSN',
#  'SBSO',
#  'SBSP',
#  'SBSR',
#  'SBSV',
#  'SBTB',
#  'SBTC',
#  'SBTE',
#  'SBTF',
#  'SBTG',
#  'SBTT',
#  'SBTU',
#  'SBUA',
#  'SBUG',
#  'SBUL',
#  'SBUR',
#  'SBUY',
#  'SBVC',
#  'SBVG',
#  'SBVH',
#  'SBVT',
#  'SBZM',
#  'SCCF',
#  'SCDA',
#  'SCEL',
#  'SCFA',
#  'SDAG',
#  'SDCO',
#  'SDIM',
#  'SDNM',
#  'SDSC',
#  'SDTK',
#  'SDUB',
#  'SDWQ',
#  'SEGU',
#  'SELT',
#  'SEQM',
#  'SGAS',
#  'SGES',
#  'SILC',
#  'SIZX',
#  'SJHG',
#  'SKBO',
#  'SKBQ',
#  'SKCL',
#  'SKLT',
#  'SKPE',
#  'SKRG',
#  'SLCB',
#  'SLLP',
#  'SLVR',
#  'SMJP',
#  'SNBR',
#  'SNCP',
#  'SNCX',
#  'SNEB',
#  'SNEE',
#  'SNGA',
#  'SNGI',
#  'SNHS',
#  'SNMA',
#  'SNMZ',
#  'SNOS',
#  'SNOX',
#  'SNRJ',
#  'SNRU',
#  'SNTF',
#  'SNTI',
#  'SNTS',
#  'SNVS',
#  'SNYA',
#  'SPJC',
#  'SSAP',
#  'SSCN',
#  'SSER',
#  'SSLT',
#  'SSOE',
#  'SSOG',
#  'SSOU',
#  'SSSB',
#  'SSSC',
#  'SSTE',
#  'SSZR',
#  'SULS',
#  'SUMU',
#  'SVBM',
#  'SVMI',
#  'SVSO',
#  'SVVA',
#  'SWCA',
#  'SWEI',
#  'SWFX',
#  'SWGN',
#  'SWHP',
#  'SWJN',
#  'SWKO',
#  'SWLB',
#  'SWLC',
#  'SWMW',
#  'SWPH',
#  'SWPI',
#  'SWTS',
#  'SYCJ',
#  'SYEC',
#  'TJBQ',
#  'TJSJ',
#  'TNCA',
#  'TTPP',
#  'UCFM',
#  'UUEE',
#  'VCBI',
#  'VHHH',
#  'VMMC',
#  'VOHS',
#  'VOMM',
#  'VTSK',
#  'VVNB',
#  'YBBN',
#  'YMML',
#  'YSSY',
#  'ZBAA',
#  'ZGGG',
#  'ZGSZ',
#  'ZHHH',
#  'ZSJN'}

# %% [markdown]
# # Carregando dados AIR_CIA

# %%
# Get all files
path = '/content/drive/MyDrive/data_eleflow/AIR_CIA/'
files = [
  path + file for file in os.listdir(path)
]

# Concat data
data = []
for file in files:
  data.append(pd.read_csv(file, delimiter=';'))
air_cia_data = pd.concat(data)

# Rename Header -> snake_case
header_name = {}
for header in air_cia_data.columns:
  header_name[header] = unidecode(header).lower().replace(' ', '_')
air_cia_data.rename(columns=header_name, inplace=True)

# Split ICAO IATA
air_cia_data[['icao', 'iata']] = air_cia_data['icao_iata'].str.split(' ', expand=True)
del air_cia_data['icao_iata']


air_cia_data = air_cia_data.drop_duplicates()
air_cia_data
# Out:
#                                          razao_social                cnpj  \
# 0                   RIMA - RIO MADEIRA AEROTÁXI LTDA.  04.778.630/0001-42
# 1                  RTS - ROTA DO SOL TÁXI AÉREO LTDA.  01.904.715/0001-31
# 0                  ABSA - AEROLINHAS BRASILEIRAS S.A.  00.074.635/0001-33
# 1   AEROSUL TÁXI AÉREO LTDA (EX.: AUSTEN TÁXI AÉRE...  27.315.694/0001-02
# 2   ASTA LINHAS AÉREAS LTDA ( EX - AMÉRICA DO SUL ...  12.703.737/0001-50
# 3                         ATA - AEROTÁXI ABAETÉ LTDA.  14.674.451/0001-19
# 4         AZUL CONECTA LTDA. (EX TWO TAXI AEREO LTDA)  04.263.318/0001-16
# 5                  AZUL LINHAS AÉREAS BRASILEIRAS S/A  09.296.295/0001-60
# 6   GOL LINHAS AÉREAS S.A. (EX- VRG LINHAS AÉREAS ...  07.575.651/0001-59
# 7                        MAP TRANSPORTES AÉREOS LTDA.  10.483.635/0001-40
# 8                MODERN TRANSPORTE AEREO DE CARGA S.A  03.887.831/0001-15
# 9                   PASSAREDO TRANSPORTES AÉREOS S.A.  00.512.777/0001-35
# 10                        SIDERAL LINHAS AÉREAS LTDA.  10.919.908/0001-57
# 11                             TAM LINHAS AÉREAS S.A.  02.012.862/0001-60
# 12                           TOTAL LINHAS AÉREAS S.A.  32.068.363/0001-55
# 2                                OMNI TÁXI AÉREO S.A.  03.670.763/0001-38
# 3                                 PRIME TÁXI AIR LTDA  23.568.370/0001-25
#
#                                     atividades_aereas  \
# 0       LIGAÇÃO AÉREA SISTEMÁTICA REGULAR, TÁXI-AÉREO
# 1   LIGAÇÃO AÉREA SISTEMÁTICA REGULAR, SERVIÇOS AÉ...
# 0                            TRANSPORTE AÉREO REGULAR
# 1   SERVIÇOS AÉREOS PÚBLICOS, TÁXI-AÉREO, TRANSPOR...
# 2   SERVIÇOS AÉREOS PÚBLICOS, TRANSPORTE AÉREO REG...
# 3   TÁXI-AÉREO, TRANSPORTE AÉREO NÃO REGULAR, TRAN...
# 4                            TRANSPORTE AÉREO REGULAR
# 5                            TRANSPORTE AÉREO REGULAR
# 6                            TRANSPORTE AÉREO REGULAR
# 7                            TRANSPORTE AÉREO REGULAR
# 8                            TRANSPORTE AÉREO REGULAR
# 9                            TRANSPORTE AÉREO REGULAR
# 10  TRANSPORTE AÉREO NÃO REGULAR, TRANSPORTE AÉREO...
# 11                           TRANSPORTE AÉREO REGULAR
# 12  SERVIÇOS AÉREOS PÚBLICOS, TRANSPORTE AÉREO REG...
# 2   AEROFOTOGRAFIA, AEROINSPEÇÃO, SERVIÇOS AÉREOS ...
# 3   TÁXI-AÉREO, TRANSPORTE AÉREO NÃO REGULAR, SERV...
#
#                                         endereco_sede  \
# 0   AV. LAURO SODRÉ, Nº 6490 - AEROPORTO INTERNACI...
# 1   PRAÇA EDUARDO GOMES, S/Nº, TERMINAL DE AVIAÇÃO...
# 0   AEROPORTO INTERNACIONAL DE VIRACOPOS, RODOVIA ...
# 1   RODOVIA PR 218, KM 7, JARDIM UNIVERSITÁRIO, AE...
# 2   AV GOVERNADOR JOÃO PONCE DE ARRUDA, S/N, HANGA...
# 3    PÇA. GAGO COUTINHO, S/N, AEROPORTO INTERNACIO...
# 4   AVENIDA EMILIO ANTONON, 901, BAIRRO CHÁCARA AE...
# 5   AV. MARCOS PENTEADO ULHÔA RODRIGUES,N°939, 9° ...
# 6   PRAÇA SENADOR SALGADO FILHO, S/N°, AEROPORTO S...
# 7   AVENIDA SANTOS DUMONT, Nº 1350, AEROPORTO INTE...
# 8   AVENIDA PREFEITO LUIZ LATORRE, Nº 9450, CONDOM...
# 9   SETOR DE HANGARES. ENTRADA PELA AV. THOMAZ ALB...
# 10  RODOVIA CONTORNO LESTE BR-116, Nº 9.119, 3º AN...
# 11  RUA ÁTICA , N° 673, 6ª ANDAR, SALA 62, JARDIM ...
# 12  AV. SENADOR SALGADO FILHO, 5397 SALA D - BAIRR...
# 2   AV. AYRTON SENNA, 2541 RUA F1 LOTE 40 - AEROPO...
# 3   AL. RIO NEGRO, 585 - BLOCO A - CJ.95 - SALA E,...
#
#                                          telefone  \
# 0                                  (69) 3225-8000
# 1                                  (85) 3272-3555
# 0                                  (11) 5582-8055
# 1                                  (43) 3176-4030
# 2                 (65) 3614-2684 / (18) 2104-1000
# 3                  (71) 34629600 / (71) 996643563
# 4                   (11) 45822355/ (11) 987433988
# 5    (55) (11) 4134-9887 | Fax: (55)(11)4134-9890
# 6                 (11) 5098-2990 / (11) 5098-7872
# 7                                   (92) 36521620
# 8                  (21) 2272-9272 / (11) 31096750
# 9                 (16) 3514-7127 / (16) 3514-7126
# 10                (41) 3116-9000 / (41) 3116-9059
# 11                (11) 5582-8055 / (11) 5582-8050
# 12                (41) 3371-8200 / (31) 3343-8600
# 2                                 (61) 98335-3444
# 3                   (11) 41958307 / (11) 41958308
#
#                                  e-mail           decisao_operacional  \
# 0                                   NaN                DECISÃO Nº 116
# 1              quadros@voerotadosol.com                 DECISÃO Nº 21
# 0                        gar@tam.com.br                 DECISÃO Nº 41
# 1              operacoes@aerosul.com.br                DECISÃO Nº 282
# 2                                   NaN                DECISÃO Nº 115
# 3          guilherme@abaete.com.br                      DECISÃO Nº 36
# 4                                   NaN  Decisão nº 14, de 25/01/2018
# 5           vanessa.reis@voeazul.com.br                Decisão nº 178
# 6            rddfonseca@voegol.com.br                  DECISÃO Nº 156
# 7                contabil@voemap.com.br                 DECISÃO Nº 89
# 8                juridico@modern.com.br                 DECISÃO Nº 79
# 9              juridico@voepass.com.br                 DECISÃO Nº 105
# 10  office@siderallinhasaereas.com.br                   DECISÃO Nº 37
# 11                    gar@tam.com.br                   DECISÃO Nº 366
# 12      geraldo.antonio@total.com.br                   DECISÃO Nº 260
# 2            lira@plfconsultoria.com.br                DECISÃO Nº 100
# 3       mmatta@primefractionclub.com.br                DECISÃO Nº 237
#
#    data_decisao_operacional validade_operacional icao  iata
# 0                26/07/2017           27/07/2022  RIM    0R
# 1                13/02/2019           15/02/2024  CKP  None
# 0                22/04/2015           23/04/2025  LTG    M3
# 1                10/02/2021                  NaN  ASO    2S
# 2                31/07/2019           02/08/2024  SUL    0A
# 3                05/03/2020                  NaN  ABJ  None
# 4                25/01/2018           29/01/2028  ACN    2F
# 5                20/11/2018           21/11/2028  AZU    AD
# 6                05/11/2019                  NaN  GLO    G3
# 7                14/08/2012           17/08/2022  PAM    7M
# 8                31/05/2017           02/06/2027  MWM    WD
# 9                09/06/2020                  NaN  PTB    2Z
# 10               05/03/2020           06/03/2025  SID    0S
# 11               07/07/2021           09/11/2031  TAM    JJ
# 12               12/01/2021           14/01/2031  TTL    L1
# 2                10/07/2019           12/07/2024  OMI    O1
# 3                17/12/2020           18/12/2025  NaN   NaN

# %% [markdown]
# # GET API Airport info

# %%
with requests.session() as session:
  url = 'https://airport-info.p.rapidapi.com/airport'
  url_head = {
    'X-RapidAPI-Key': '4c13e6c3eemsh73f49fcc12e4e57p1483c0jsn7d15bfd7c8ff',
    'X-RapidAPI-Host': 'airport-info.p.rapidapi.com',
  }
  session.headers.update(url_head)

  airport_infos = list()
  for icao in icao_codes:
    url_par = {'icao': icao}
    response = session.get(
        url, headers=url_head, params=url_par
    )

    if response.status_code != 200:
        msg = f'Airtable API returned {response.status_code}'
        print(msg)

    airport_infos.append(response.json())

airport_infos = pd.DataFrame(airport_infos)
airport_infos
# Out:
#          id iata  icao                                 name  \
# 0     268.0  AMS  EHAM           Amsterdam Airport Schiphol
# 1    1399.0  CMB  VCBI   Bandaranaike International Airport
# 2    3290.0  ISL  LTFM                 Istanbul New Airport
# 3     212.0  AKL  NZAA                     Auckland Airport
# 4    1141.0  CAF  SWCA                     Carauari Airport
# ..      ...  ...   ...                                  ...
# 310  1367.0  CKS  SBCJ                      Carajás Airport
# 311  3395.0  JDO  SBJU            Juazeiro do Norte Airport
# 312  4202.0  LIS  LPPT               Lisbon Portela Airport
# 313  4838.0  MOC  SBMK  Montes Claros/Mário Ribeiro Airport
# 314     NaN  NaN   NaN                                  NaN
#
#                                 location street_number  \
# 0                 Amsterdam, Netherlands           202
# 1                     Colombo, Sri Lanka
# 2                       Istanbul, Turkey
# 3                  Auckland, New Zealand
# 4             Carauari, Amazonas, Brazil       600-628
# ..                                   ...           ...
# 310            Parauapebas, Pará, Brazil
# 311     Juazeiro do Norte, Ceará, Brazil          4000
# 312                     Lisbon, Portugal
# 313  Montes Claros, Minas Gerais, Brazil
# 314                                  NaN           NaN
#
#                                   street      city             county  \
# 0                Evert van de Beekstraat  Schiphol     Haarlemmermeer
# 1                   Canada Friendship Rd   කටුනායක              ගම්පහ
# 2                                                            Bakırköy
# 3                        Ray Emery Drive  Auckland
# 4              Avenida Dom Pedro Segundo                     Carauari
# ..                                   ...       ...                ...
# 310                                                       Parauapebas
# 311              Avenida Virgílio Távora            Juazeiro do Norte
# 312  Alameda das Comunidades Portuguesas    Lisboa
# 313       Avenida Comandante João Milton                Montes Claros
# 314                                  NaN       NaN                NaN
#
#                           state country_iso      country postal_code  \
# 0                 Noord-Holland          NL  Netherlands     1118 CP
# 1    බස්නාහිර පළාත, ශ් රී ලංකාව          LK    Sri Lanka       11450
# 2                      Istanbul          TR       Turkey       34149
# 3                      Auckland          NZ  New Zealand        2022
# 4                      Amazonas          BR       Brazil   69500-000
# ..                          ...         ...          ...         ...
# 310                        Pará          BR       Brazil   68515-000
# 311                       Ceará          BR       Brazil   63020-735
# 312                      Lisboa          PT     Portugal    1700-111
# 313                Minas Gerais          BR       Brazil   39404-844
# 314                         NaN         NaN          NaN         NaN
#
#                  phone   latitude   longitude    uct  \
# 0      +31 20 794 0800  52.310540    4.768274  120.0
# 1      +94 112 264 444   7.180155   79.884254  330.0
# 2    +90 212 463 30 00  40.982990   28.810442  180.0
# 3       +64 9-275 0789 -37.008247  174.785030  780.0
# 4                       -4.875501  -66.899160 -240.0
# ..                 ...        ...         ...    ...
# 310  +55 94 98403-1335  -6.114454  -50.001007 -180.0
# 311   +55 88 3311-6500  -7.215097  -39.272230 -180.0
# 312   +351 21 841 3500  38.775593   -9.135366   60.0
# 313   +55 38 3229-1200 -16.704617  -43.820087 -180.0
# 314                NaN        NaN         NaN    NaN
#
#                                                website  \
# 0                              http://www.schiphol.nl/
# 1                               http://www.airport.lk/
# 2                       http://www.ataturkairport.com/
# 3                    http://www.aucklandairport.co.nz/
# 4
# ..                                                 ...
# 310                        http://www.infraero.gov.br/
# 311  http://www4.infraero.gov.br/aeroportos/aeropor...
# 312  http://www.ana.pt/pt-PT/Aeroportos/Lisboa/Lisb...
# 313  http://www4.infraero.gov.br/aeroportos/aeropor...
# 314                                                NaN
#
#                             error
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ..                            ...
# 310                           NaN
# 311                           NaN
# 312                           NaN
# 313                           NaN
# 314  {'text': 'No airport found'}
#
# [315 rows x 19 columns]

# %% [markdown]
# # Creating Data Base

# %%
conn = sqlite3.connect('eleflow.db')
cursor = conn.cursor()

create_airport_infos = """
CREATE TABLE airport_infos (
  id INTEGER PRIMARY KEY,
  iata VARCHAR(20),
  icao VARCHAR(20),
  name VARCHAR(100),
  location VARCHAR(100),
  street_number VARCHAR(20),
  street VARCHAR(50),
  city VARCHAR(50),
  county VARCHAR(50),
  state VARCHAR(20),
  country_iso VARCHAR(2),
  country VARCHAR(100),
  postal_code VARCHAR(100),
  phone VARCHAR(100),
  latitude NUMERIC,
  longitude NUMERIC,
  uct NUMERIC,
  website VARCHAR(100),
  error VARCHAR(100)
);
"""

cursor.execute(create_airport_infos)

create_vra = """
CREATE TABLE vra (
  id INTEGER PRIMARY KEY AUTOINCREMENT,
  icao_empresa_aerea VARCHAR(20),
  numero_voo VARCHAR(20),
  codigo_autorizacao VARCHAR(20),
  codigo_tipo_linha VARCHAR(2),
  icao_aerodromo_origem VARCHAR(20),
  icao_aerodromo_destino VARCHAR(20),
  partida_prevista TIMESTAMP,
  partida_real TIMESTAMP,
  chegada_prevista TIMESTAMP,
  chegada_real TIMESTAMP,
  situacao_voo VARCHAR(20),
  codigo_justificativa VARCHAR(20)
);
"""

cursor.execute(create_vra)

create_air_cia = """
CREATE TABLE air_cia (
  id INTEGER PRIMARY KEY AUTOINCREMENT,
  razao_social VARCHAR(50),
  cnpj VARCHAR(30),
  atividades_aereas VARCHAR(50),
  endereco_sede VARCHAR(50),
  telefone VARCHAR(20),
  email VARCHAR(30),
  decisao_operacional VARCHAR(50),
  data_decisao_operacional date,
  validade_operacional date,
  icao VARCHAR(10),
  iata VARCHAR(10)
);
"""

cursor.execute(create_air_cia)

# %% [markdown]
# # Insert data in DB

# %% [markdown]
# ### Airport Info

# %%
values = list()
for index, row in airport_infos.iterrows():
  if str(row['icao']) == 'nan':
    continue
 
  values.append("({}, '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', {}, {}, {}, '{}', '{}')".format(
    int(row['id']),
    row['iata'],
    row['icao'],
    row['name'].replace("'", "''"),
    row['location'].replace("'", "''"),
    row['street_number'],
    row['street'].replace("'", "''"),
    row['city'].replace("'", "''"),
    row['county'].replace("'", "''"),
    row['state'].replace("'", "''"),
    row['country_iso'],
    row['country'].replace("'", "''"),
    row['postal_code'],
    row['phone'],
    row['latitude'],
    row['longitude'],
    row['uct'],
    row['website'],
    row['error']
  ))

sql = 'insert into airport_infos(id,iata,icao,name,location,street_number,street,city,county,state,country_iso,country,postal_code,phone,latitude,longitude,uct,website,error) values\n'
sql += ','.join(values) + ';'
cursor.execute(sql)

# %% [markdown]
# ### VRA

# %%
values = list()
for index, row in vra_data.iterrows():

  values.append("('{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}')".format(
    row['icao_empresa_aerea'],
    row['numero_voo'],
    row['codigo_autorizacao'],
    row['codigo_tipo_linha'],
    row['icao_aerodromo_origem'],
    row['icao_aerodromo_destino'],
    row['partida_prevista'],
    row['partida_real'],
    row['chegada_prevista'],
    row['chegada_real'],
    row['situacao_voo'],
    row['codigo_justificativa'],
  ))

sql_vra = 'insert into vra(icao_empresa_aerea,numero_voo,codigo_autorizacao,codigo_tipo_linha,icao_aerodromo_origem,icao_aerodromo_destino,partida_prevista,partida_real,chegada_prevista,chegada_real,situacao_voo,codigo_justificativa) values\n'
sql_vra += ','.join(values) + ';'
cursor.execute(sql_vra)

# %% [markdown]
# ### AIR CIA

# %%
values = list()
for index, row in air_cia_data.iterrows():
 
  values.append("('{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}')".format(
    row['razao_social'],
    row['cnpj'],
    row['atividades_aereas'],
    row['endereco_sede'],
    row['telefone'],
    row['e-mail'],
    row['decisao_operacional'],
    row['data_decisao_operacional'],
    row['validade_operacional'],
    row['icao'],
    row['iata']
  ))

sql = 'insert into air_cia(razao_social,cnpj,atividades_aereas,endereco_sede,telefone,email,decisao_operacional,data_decisao_operacional,validade_operacional,icao,iata) values\n'
sql += ','.join(values) + ';'
cursor.execute(sql)

# %% [markdown]
# # Checking DB

# %%
cursor.execute('select count(*) from airport_infos;')
airport_db = cursor.fetchall()

cursor.execute("select count(*) from vra;")
vra_db = cursor.fetchall()

cursor.execute("select count(*) from air_cia;")
air_cia_db = cursor.fetchall()

# %%
airport_db
# Out:
# [(276,)]

# %%
vra_db
# Out:
# [(535803,)]

# %%
air_cia_db
# Out:
# [(17,)]

# %% [markdown]
# # SQL VIEWS

# %%
first_query = """
WITH base as (
  SELECT
    icao_empresa_aerea,
    icao_aerodromo_origem,
    icao_aerodromo_destino,
    ROW_NUMBER() OVER(
      PARTITION BY icao_empresa_aerea
      ORDER BY count(*) DESC
    ) as row_
  FROM vra
  GROUP BY 1,2,3
  order by 1 DESC
)
SELECT
  COALESCE(air_cia.razao_social, base.icao_empresa_aerea) as 'Companhia Aérea',
  COALESCE(ai1.name, base.icao_aerodromo_origem) as 'Aeroporto Origem',
  base.icao_aerodromo_origem as 'ICAO Aeroporto Origem',
  ai1.state as 'Estado Aeroporto Origem',
  COALESCE(ai2.name, base.icao_aerodromo_destino) as 'Aeroporto Destino',
  base.icao_aerodromo_destino as 'ICAO Aeroporto Destino',
  ai2.state as 'Estado Aeroporto Destino'
FROM base
LEFT JOIN air_cia
  on base.icao_empresa_aerea = air_cia.icao
LEFT JOIN airport_infos ai1
  on base.icao_aerodromo_origem = ai1.icao
LEFT JOIN airport_infos ai2
  on base.icao_aerodromo_destino = ai2.icao
WHERE base.row_ = 1
"""

first_result = pd.read_sql_query(first_query, conn)
first_result
# Out:
#                                  Companhia Aérea  \
# 0                                            VVC
# 1                                            VDA
# 2                                            UPS
# 3                                            UKL
# 4                                            UAL
# ..                                           ...
# 105                                          AEA
# 106                                          ADB
# 107  AZUL CONECTA LTDA. (EX TWO TAXI AEREO LTDA)
# 108                                          ACA
# 109                                          AAL
#
#                                       Aeroporto Origem ICAO Aeroporto Origem  \
# 0                      El Dorado International Airport                  SKBO
# 1    Recife/Guararapes–Gilberto Freyre Internationa...                  SBRF
# 2                          Miami International Airport                  KMIA
# 3                 George Bush Intercontinental Airport                  KIAH
# 4            São Paulo–Guarulhos International Airport                  SBGR
# ..                                                 ...                   ...
# 105               Adolfo Suárez Madrid–Barajas Airport                  LEMD
# 106           Johan Adolf Pengel International Airport                  SMJP
# 107                                      Coari Airport                  SWKO
# 108          São Paulo–Guarulhos International Airport                  SBGR
# 109          São Paulo–Guarulhos International Airport                  SBGR
#
#     Estado Aeroporto Origem  \
# 0                    Bogotá
# 1                Pernambuco
# 2                   Florida
# 3                     Texas
# 4                 São Paulo
# ..                      ...
# 105     Comunidad de Madrid
# 106                    Para
# 107       State of Amazonas
# 108               São Paulo
# 109               São Paulo
#
#                                      Aeroporto Destino ICAO Aeroporto Destino  \
# 0    Tancredo Neves International Airport (Confins ...                   SBCF
# 1          Rio de Janeiro–Galeão International Airport                   SBGL
# 2             Viracopos/Campinas International Airport                   SBKP
# 3                  Norman Manley International Airport                   MKJP
# 4                 Newark Liberty International Airport                   KEWR
# ..                                                 ...                    ...
# 105          São Paulo–Guarulhos International Airport                   SBGR
# 106                  Val de Cans International Airport                   SBBE
# 107                Eduardo Gomes International Airport                   SBEG
# 108              Toronto Pearson International Airport                   CYYZ
# 109                        Miami International Airport                   KMIA
#
#     Estado Aeroporto Destino
# 0               Minas Gerais
# 1             Rio de Janeiro
# 2                  São Paulo
# 3            Kingston Parish
# 4                 New Jersey
# ..                       ...
# 105                São Paulo
# 106                     Pará
# 107                 Amazonas
# 108                  Ontario
# 109                  Florida
#
# [110 rows x 7 columns]

# %%
second_query = """
WITH RECURSIVE split(icao_empresa_aerea, aeroporto, str) AS (
    SELECT icao_empresa_aerea, '', aeroportos||';'
    FROM (
      SELECT
        icao_empresa_aerea,
        icao_aerodromo_origem || ';' || icao_aerodromo_destino as aeroportos
      FROM vra
    )
    UNION ALL
    SELECT
      icao_empresa_aerea,
      substr(str, 0, instr(str, ';')),
      substr(str, instr(str, ';') +1)
    FROM split WHERE str!=''
), base as (
  SELECT
    icao_empresa_aerea,
    aeroporto
  FROM split
  WHERE aeroporto != ''
), max as (
  SELECT
    aeroporto,
    icao_empresa_aerea,
    total_dp
  FROM (
      SELECT
        aeroporto,
        icao_empresa_aerea,
        count(*) as total_dp,
        ROW_NUMBER() OVER(
            PARTITION BY aeroporto
            ORDER BY count(*) DESC
          ) as row_
      FROM base
      GROUP BY 1, 2
  )
  WHERE row_ = 1
), partidas as (
  SELECT
    max.aeroporto,
    max.icao_empresa_aerea,
    count(*) as partidas
  FROM max
  JOIN vra
    on max.aeroporto = vra.icao_aerodromo_origem
    and max.icao_empresa_aerea = vra.icao_empresa_aerea
  GROUP BY 1, 2
), chegadas as (
  SELECT
    max.aeroporto,
    max.icao_empresa_aerea,
    count(*) as chegadas
  FROM max
  JOIN vra
    on max.aeroporto = vra.icao_aerodromo_destino
    and max.icao_empresa_aerea = vra.icao_empresa_aerea
  GROUP BY 1, 2
)
SELECT
  COALESCE(airport_infos.name, max.aeroporto) as 'Aeroporto',
  max.aeroporto as 'ICAO Aeroporto',
  COALESCE(air_cia.razao_social, max.icao_empresa_aerea) as 'Companhia Aérea',
  max.total_dp as 'Total de Decolagens e Pousos',
  CAST(partidas.partidas as INTERGER) as 'Total de Decolagens',
  CAST(chegadas.chegadas as INTERGER) as 'Total de Pousos'
FROM max
LEFT JOIN airport_infos
  on max.aeroporto = airport_infos.icao
LEFT JOIN air_cia
  on max.icao_empresa_aerea = air_cia.icao
LEFT JOIN partidas
  on max.aeroporto = partidas.aeroporto
LEFT JOIN chegadas
  on max.aeroporto = chegadas.aeroporto
ORDER BY 1;
"""

second_result = pd.read_sql_query(second_query, conn)
second_result
# Out:
#                                     Aeroporto ICAO Aeroporto  \
# 0             Abu Dhabi International Airport           OMAA
# 1        Adolfo Suárez Madrid–Barajas Airport           LEMD
# 2           Afonso Pena International Airport           SBCT
# 3                   Agadir–Al Massira Airport           GMAD
# 4    Alberto Alcolumbre International Airport           SBMQ
# ..                                        ...            ...
# 310   Washington Dulles International Airport           KIAD
# 311        Wuhan Tianhe International Airport           ZHHH
# 312                          Zaragoza Airport           LEZG
# 313  Zumbi dos Palmares International Airport           SBMO
# 314                            Zürich Airport           LSZH
#
#                                        Companhia Aérea  \
# 0                                                  ETD
# 1                                                  IBE
# 2                   AZUL LINHAS AÉREAS BRASILEIRAS S/A
# 3                                                  MEM
# 4    GOL LINHAS AÉREAS S.A. (EX- VRG LINHAS AÉREAS ...
# ..                                                 ...
# 310                                                UAL
# 311                                                ETH
# 312                                                QTR
# 313                 AZUL LINHAS AÉREAS BRASILEIRAS S/A
# 314                                                SWR
#
#      Total de Decolagens e Pousos  Total de Decolagens  Total de Pousos
# 0                              12                  6.0              6.0
# 1                             656                331.0            325.0
# 2                           12352               6177.0           6175.0
# 3                               2                  1.0              1.0
# 4                            1327                663.0            664.0
# ..                            ...                  ...              ...
# 310                             8                  4.0              4.0
# 311                             4                  4.0              NaN
# 312                             6                  3.0              3.0
# 313                          4372               2186.0           2186.0
# 314                           555                270.0            285.0
#
# [315 rows x 6 columns]
